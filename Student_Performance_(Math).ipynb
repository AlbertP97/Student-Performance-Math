# %% [markdown]
# <a href="https://colab.research.google.com/github/AlbertP97/Student-Performance-Math/blob/main/Student_Performance_(Math).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Importing Libraries

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. Reading the Dataset

# %%
# Reading the dataset
math_dataset =pd.read_csv('/content/drive/MyDrive/Portafolio DS/Datasets/student-mat.csv', delimiter=';')
math_dataset.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# # 3. Basic Data Exploration

# %%
# Basic data exploration
print(math_dataset.shape)
# Out:
# (395, 33)

# %%
math_dataset.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
# Additional data exploration and information
math_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
math_dataset.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %% [markdown]
# # 4. Visualizing Categorical Data

# %%
# Visualizing categorical data
plt.figure(figsize=(12, 8))
math_dataset['school'].value_counts().plot(kind='pie')
plt.title('School: GP - Gabriel Pereira or MS - Mousinho da Silveira')
plt.show()

# %%
plt.figure(figsize=(12, 8))
math_dataset['sex'].value_counts().plot(kind="pie")
plt.title('Sex')
plt.show()

# %%
plt.figure(figsize=(12, 8))
math_dataset['age'].value_counts().plot(kind="bar")
plt.title('Age of students')
plt.show()

# %% [markdown]
# # 5. Visualizing Relationships and Distributions

# %%
# Visualizing relationships and distributions using Seaborn
plt.figure(figsize=(12, 8))
sns.countplot(data=math_dataset, x="age", hue="sex")
plt.title('Age & sex of students')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='age',y='G3', data=math_dataset)
plt.title('Age & G3 (Last grade)')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=math_dataset, x="famsize", hue="sex")
plt.title('Family size: LE3 - less or equal to 3 or GT3 - greater than 3 & Sex')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x="Pstatus", y="G3", data=math_dataset)
plt.title("Parent's status: T - living together or A - apart & G3 (Last grade)")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x="guardian", y="G3", data=math_dataset)
plt.title('Guardian & G3 (Last grade)')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=math_dataset, x="Medu", hue="sex")
plt.title('Mother education level by student sex:  0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=math_dataset, x="Mjob", hue="sex")
plt.title('Mother job type by student sex')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=math_dataset, x="Fjob", hue="sex")
plt.title('Father job type by student sex')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=math_dataset, x="reason", hue="sex")
plt.title('Reason to choose this school by student sex')
plt.show()

# %%
plt.figure(figsize=(12, 8))
math_dataset["schoolsup"].value_counts().plot(kind="pie")
plt.title('Extra educational support')
plt.show()

# %%
plt.figure(figsize=(12, 8))
math_dataset["famsup"].value_counts().plot(kind="pie")
plt.title('Family educational support')
plt.show()

# %%
plt.figure(figsize=(12, 8))
math_dataset["paid"].value_counts().plot(kind="pie")
plt.title('Extra paid classes')
plt.show()

# %%
plt.figure(figsize=(12, 8))
math_dataset["internet"].value_counts().plot(kind="pie")
plt.title('Students want to take higher education & G3')
plt.show()

# %%
# Visualizing relationships using hexbin plots
math_dataset.plot.hexbin(x="Medu",y="G3",gridsize=10)
plt.title('Mother education & G3 (Last grade))')
plt.show()

# %%
math_dataset.plot.hexbin(x="Fedu",y="G3",gridsize=10)
plt.title('Father education & G3 (Last grade)')
plt.show()

# %% [markdown]
# # 6. Visualizing Correlation Matrix

# %%
# Heatmap for correlation visualization
plt.figure(figsize=(12, 8))
sns.heatmap(math_dataset.corr(numeric_only=True))
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # 7. Data Subset

# %%
# Creating a subset of the dataset for modeling
math_dataset_2 = math_dataset[["G1", "G2", "G3", "failures", "studytime", "freetime", "absences", "health", "Dalc", "Walc", "famrel", "schoolsup", "internet",]].copy()
math_dataset_2.head()
# Out:
#    G1  G2  G3  failures  studytime  freetime  absences  health  Dalc  Walc  \
# 0   5   6   6         0          2         3         6       3     1     1
# 1   5   5   6         0          2         3         4       3     1     1
# 2   7   8  10         3          2         3        10       3     2     3
# 3  15  14  15         0          3         2         2       5     1     1
# 4   6  10  10         0          2         3         4       5     1     2
#
#    famrel schoolsup internet
# 0       4       yes       no
# 1       5        no      yes
# 2       4       yes      yes
# 3       3        no      yes
# 4       4        no       no

# %%
# Regression plot based on study time and grades
plt.figure(figsize=(12, 8))
plt.title("Grades based on study time")
sns.regplot(x="studytime", y="G1", data=math_dataset_2, color="orange",label="G1: First Period Grades", scatter= False, ci= None)
sns.regplot(x="studytime", y="G2", data=math_dataset_2, color="red", label="G2: Second Period Grades", scatter= False, ci= None)
sns.regplot(x="studytime", y="G3", data=math_dataset_2, color="blue", label="G3: Final Period Grades", scatter= False, ci= None)
plt.xlabel("Study Time")
plt.ylabel("Grades")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # 8. Multiple Linear Regression Modeling

# %%
# Linear regression model creation and evaluation
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# Define X (Features) and y (Labels) variables
X = math_dataset_2["studytime"]
y = math_dataset_2["G3"]

# %%
# Function to create linear regression models
def linear_model(df, feature_variables, target_variable):
  X = np.array(df[feature_variables])
  y = np.array(df[target_variable])

  # Splitting the data into training and testing sets
  X_train, X_test, y_train, y_test = train_test_split(X,
                                                      y,
                                                      test_size=0.2,
                                                      random_state=0)

  # Creating and fitting the linear regression model
  lr = LinearRegression()
  lr.fit(X_train, y_train)

  # Making predictions and creating a dataframe for results
  y_pred = lr.predict(X_test)
  dictionary = {}

  for feature in feature_variables:
    dictionary[feature] = X_test[:, feature_variables.index(feature)]

  lr_results = pd.DataFrame.from_dict(dictionary)
  lr_results["Ground Truth"] = y_test
  lr_results["Prediction"] = y_pred

  # Printing model evaluation metrics
  print("Target:",target_variable)
  print("Features:", feature_variables)
  print("The accuracy of the model is:", lr.score(X_test, y_test))
  print("The MAE of the model is:", mean_absolute_error(y_test, y_pred))
  print("The intercept (alpha) is:", lr.intercept_)
  print("The coeficients (betas) are: ", lr.coef_)

  return lr_results.head()

# %%
# Usage of linear_model with different sets of features
linear_model(math_dataset_2, ["G1", "G2", "studytime"], "G3")
# Out:
# Target: G3
# Features: ['G1', 'G2', 'studytime']
# The accuracy of the model is: 0.8045226291995431
# The MAE of the model is: 1.315429758099135
# The intercept (alpha) is: -1.3306401074773113
# The coeficients (betas) are:  [ 0.09957709  1.01511826 -0.05954176]
#    G1  G2  studytime  Ground Truth  Prediction
# 0  14  14          3            14   14.096470
# 1  11  11          3            10   10.752384
# 2   9  10          3             9    9.538111
# 3  16  15          2            15   15.370284
# 4  15  16          2            16   16.285825

# %%
linear_model(math_dataset_2, ["G1", "G2", "studytime", "freetime", "failures", "absences"], "G3")
# Out:
# Target: G3
# Features: ['G1', 'G2', 'studytime', 'freetime', 'failures', 'absences']
# The accuracy of the model is: 0.8058474034843861
# The MAE of the model is: 1.375674295047755
# The intercept (alpha) is: -1.5257907757041238
# The coeficients (betas) are:  [ 0.08756474  1.01019515 -0.03869629  0.05175316 -0.30469628  0.04755664]
#    G1  G2  studytime  freetime  failures  absences  Ground Truth  Prediction
# 0  14  14          3         3         0         4            14   14.072245
# 1  11  11          3         3         0         0            10   10.588739
# 2   9  10          3         3         0         9             9    9.831424
# 3  16  15          2         4         0         2            15   15.252906
# 4  15  16          2         2         0         2            16   16.072030

# %%
linear_model(math_dataset_2, ["G1", "G2", "studytime", "freetime", "absences"], "G3")
# Out:
# Target: G3
# Features: ['G1', 'G2', 'studytime', 'freetime', 'absences']
# The accuracy of the model is: 0.8052780151687997
# The MAE of the model is: 1.3746729660661283
# The intercept (alpha) is: -1.835857416031276
# The coeficients (betas) are:  [ 0.10009996  1.01807136 -0.0224504   0.04413379  0.04404144]
#    G1  G2  studytime  freetime  absences  Ground Truth  Prediction
# 0  14  14          3         3         4            14   14.059757
# 1  11  11          3         3         0            10   10.529077
# 2   9  10          3         3         9             9    9.707179
# 3  16  15          2         4         2            15   15.256530
# 4  15  16          2         2         2            16   16.086233

# %%
linear_model(math_dataset_2, ["G1", "G2", "studytime", "health"], "G3")
# Out:
# Target: G3
# Features: ['G1', 'G2', 'studytime', 'health']
# The accuracy of the model is: 0.8024468627760967
# The MAE of the model is: 1.3489691097619598
# The intercept (alpha) is: -1.785273595791919
# The coeficients (betas) are:  [ 0.09486168  1.0216824  -0.04911416  0.11626203]
#    G1  G2  studytime  health  Ground Truth  Prediction
# 0  14  14          3       4            14   14.164049
# 1  11  11          3       5            10   10.930679
# 2   9  10          3       5             9    9.719273
# 3  16  15          2       1            15   15.075783
# 4  15  16          2       5            16   16.467652

# %%
linear_model(math_dataset_2, ["G1", "G2", "studytime", "failures", "Dalc", "famrel"], "G3")
# Out:
# Target: G3
# Features: ['G1', 'G2', 'studytime', 'failures', 'Dalc', 'famrel']
# The accuracy of the model is: 0.8153233051475112
# The MAE of the model is: 1.2720986763749842
# The intercept (alpha) is: -1.8599289556530074
# The coeficients (betas) are:  [ 0.08346101  1.01577929 -0.08303818 -0.24495024  0.03563467  0.19579156]
#    G1  G2  studytime  failures  Dalc  famrel  Ground Truth  Prediction
# 0  14  14          3         0     1       4            14   14.099122
# 1  11  11          3         0     2       4            10   10.837035
# 2   9  10          3         0     1       4             9    9.618699
# 3  16  15          2         0     1       5            15   15.560653
# 4  15  16          2         0     1       4            16   16.297179

# %%
linear_model(math_dataset_2, ["G1", "G2", "studytime", "failures", "Walc", "famrel"], "G3")
# Out:
# Target: G3
# Features: ['G1', 'G2', 'studytime', 'failures', 'Walc', 'famrel']
# The accuracy of the model is: 0.8166812610900266
# The MAE of the model is: 1.2875730854203116
# The intercept (alpha) is: -2.2411122105326093
# The coeficients (betas) are:  [ 0.08814988  1.01317833 -0.0460849  -0.25875831  0.11824563  0.21260592]
#    G1  G2  studytime  failures  Walc  famrel  Ground Truth  Prediction
# 0  14  14          3         0     2       4            14   14.126143
# 1  11  11          3         0     5       4            10   11.176895
# 2   9  10          3         0     1       4             9    9.514435
# 3  16  15          2         0     2       5            15   15.574312
# 4  15  16          2         0     1       4            16   16.168489

# %%
linear_model(math_dataset_2, ["G1", "G2", "failures", "studytime", "freetime", "absences", "health", "Dalc", "Walc", "famrel"], "G3")
# Out:
# Target: G3
# Features: ['G1', 'G2', 'failures', 'studytime', 'freetime', 'absences', 'health', 'Dalc', 'Walc', 'famrel']
# The accuracy of the model is: 0.8112536192626402
# The MAE of the model is: 1.3905871600162243
# The intercept (alpha) is: -2.791600949200113
# The coeficients (betas) are:  [ 0.08011306  1.02224225 -0.30227199 -0.02640678  0.00945686  0.04914748
#   0.12028675 -0.13162096  0.12480265  0.20305091]
#    G1  G2  failures  studytime  freetime  absences  health  Dalc  Walc  \
# 0  14  14         0          3         3         4       4     1     2
# 1  11  11         0          3         3         0       5     2     5
# 2   9  10         0          3         3         9       5     1     1
# 3  16  15         0          2         4         2       1     1     2
# 4  15  16         0          2         2         2       5     1     1
#
#    famrel  Ground Truth  Prediction
# 0       4            14   14.198449
# 1       4            10   11.057866
# ...
